# %%
import pandas as pd

# %%
bet_totals = pd.read_csv(r'C:\Users\redye\Desktop\NBACrit\nba_betting_totals.csv')
games = pd.read_csv(r'C:\Users\redye\Desktop\NBACrit\nba_games_all.csv')
teams = pd.read_csv(r'C:\Users\redye\Desktop\NBACrit\nba_teams_all.csv')
bet_totals
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  total1  \
# 0       21100131  Pinnacle Sports      238  1610612740  1610612743   192.0
# 1       21100131           5Dimes       19  1610612740  1610612743   192.0
# 2       21100131        Bookmaker       93  1610612740  1610612743   192.0
# 3       21100131        BetOnline     1096  1610612740  1610612743   191.5
# 4       21100131           Bovada   999996  1610612740  1610612743   192.0
# ...          ...              ...      ...         ...         ...     ...
# 131381  41700215         Heritage      169  1610612755  1610612738   204.5
# 131382  41700215        Intertops      180  1610612755  1610612738   205.0
# 131383  41700215         YouWager      139  1610612755  1610612738   204.5
# 131384  41700215          JustBet     1275  1610612755  1610612738   204.0
# 131385  41700215    Sportsbetting   999991  1610612755  1610612738   204.5
#
#         total2  price1  price2
# 0        192.0  -105.0  -105.0
# ...

# %%
games
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1       20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2       20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3       20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4       20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 125619  20801131  2009-04-03    MIN @ UTA  1610612762       t  L  46.0  30.0
# 125620  20801058  2009-03-24    HOU @ UTA  1610612762       t  W  44.0  26.0
# 125621  20801029  2009-03-20  OKC vs. UTA  1610612762       f  W  43.0  26.0
# 125622  20800839  2009-02-23    ATL @ UTA  1610612762       t  W  34.0  23.0
# 125623  20800810  2009-02-19    BOS @ UTA  1610612762       t  W  32.0  23.0
#
# ...

# %%
teams
# Out:
#     league_id     team_id  min_year  max_year abbreviation
# 0           0  1610612737    1949.0    2018.0          ATL
# 1           0  1610612738    1946.0    2018.0          BOS
# 2           0  1610612739    1970.0    2018.0          CLE
# 3           0  1610612740    2002.0    2018.0          NOP
# 4           0  1610612741    1966.0    2018.0          CHI
# ..        ...         ...       ...       ...          ...
# 64          0  1610610023    1949.0    1949.0          NaN
# 65          0  1610610026    1946.0    1946.0          NaN
# 66          0  1610610028    1946.0    1946.0          NaN
# 67          0  1610610032    1946.0    1948.0          NaN
# 68          0  1610610035    1946.0    1946.0          NaN
#
# [69 rows x 5 columns]

# %%
merged_df = pd.merge(games, teams, on='team_id')
nba_df = pd.merge(merged_df, bet_totals, on=['team_id', 'game_id', 'a_team_id'])
nba_df
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 2       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 3       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 4       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 131381  20700669  2008-01-30  NOH vs. GSW  1610612744       f  W  28.0  19.0
# 131382  20700669  2008-01-30  NOH vs. GSW  1610612744       f  W  28.0  19.0
# 131383  20700669  2008-01-30  NOH vs. GSW  1610612744       f  W  28.0  19.0
# 131384  20700669  2008-01-30  NOH vs. GSW  1610612744       f  W  28.0  19.0
# 131385  20700669  2008-01-30  NOH vs. GSW  1610612744       f  W  28.0  19.0
#
# ...

# %%
nba_df.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 2  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 3  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 4  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
#
#    w_pct  min  ...  league_id  min_year  max_year  abbreviation  \
# 0  0.569  240  ...          0    1974.0    2018.0           UTA
# 1  0.569  240  ...          0    1974.0    2018.0           UTA
# 2  0.569  240  ...          0    1974.0    2018.0           UTA
# 3  0.569  240  ...          0    1974.0    2018.0           UTA
# 4  0.569  240  ...          0    1974.0    2018.0           UTA
#
#          book_name  book_id  total1  total2  price1  price2
# 0  Pinnacle Sports      238   215.0   215.0  -117.0   107.0
# ...

# %%
nba_df['game_date'] = pd.to_datetime(nba_df['game_date'])

# Create a boolean mask to filter rows with dates between "9/30/2017" and "6/8/2018"
mask = (nba_df['game_date'] >= '2017-09-30') & (nba_df['game_date'] <= '2018-06-08')

# Use the mask to filter the rows and create a new DataFrame containing the desired dates
nba2017 = final_merged_df.loc[mask]
nba2017
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 675     21701201  2018-04-08  LAL vs. UTA  1610612762       f  W  47.0  33.0
# 676     21701201  2018-04-08  LAL vs. UTA  1610612762       f  W  47.0  33.0
# 677     21701201  2018-04-08  LAL vs. UTA  1610612762       f  W  47.0  33.0
# 678     21701201  2018-04-08  LAL vs. UTA  1610612762       f  W  47.0  33.0
# 679     21701201  2018-04-08  LAL vs. UTA  1610612762       f  W  47.0  33.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 131320  21700263  2017-11-22  OKC vs. GSW  1610612744       f  L  13.0   5.0
# 131321  21700263  2017-11-22  OKC vs. GSW  1610612744       f  L  13.0   5.0
# 131322  21700263  2017-11-22  OKC vs. GSW  1610612744       f  L  13.0   5.0
# 131323  21700263  2017-11-22  OKC vs. GSW  1610612744       f  L  13.0   5.0
# 131324  21700263  2017-11-22  OKC vs. GSW  1610612744       f  L  13.0   5.0
#
# ...

# %%
nba2017.to_csv(r'C:\Users\redye\Desktop\NBACrit\nba2017.csv', index=False)
