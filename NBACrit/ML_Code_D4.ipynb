# %%
# Import the modules
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Read the CSV file 
nba_df = pd.read_csv("C:/Users/tsswi/OneDrive/Desktop/DU_Classwork/Module_23_Project4/merged_df.csv")

# %%
# Review the DataFrame
nba_df.head(10)
# Out:
#   GAME_DATE_EST   game_id   home_team   away_team  SEASON  PTS_home  \
# 0    2017-09-30  11700001  1610612744  1610612743    2017     102.0
# 1    2017-09-30  11700002  1610612747  1610612750    2017      99.0
# 2    2017-11-01  21700111  1610612752  1610612745    2017      97.0
# 3    2017-11-01  21700107  1610612755  1610612737    2017     119.0
# 4    2017-11-01  21700108  1610612764  1610612756    2017     116.0
# 5    2017-11-01  21700110  1610612748  1610612741    2017      97.0
# 6    2017-11-01  21700115  1610612762  1610612757    2017     112.0
# 7    2017-11-01  21700109  1610612738  1610612758    2017     113.0
# 8    2017-11-01  21700113  1610612740  1610612750    2017      98.0
# 9    2017-11-01  21700114  1610612743  1610612761    2017     129.0
#
#    FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  over_odds  \
# 0        0.411        0.833         0.121      17.0  ...     -110.0
# 1        0.441        0.706         0.167      27.0  ...     -110.0
# 2        0.433        0.846         0.308      23.0  ...     -107.0
# 3        0.465        0.560         0.371      36.0  ...     -104.0
# 4        0.446        0.800         0.333      20.0  ...     -105.0
# 5        0.410        0.895         0.387      21.0  ...     -105.0
# 6        0.378        0.861         0.448      16.0  ...     -105.0
# 7        0.488        0.842         0.415      30.0  ...     -101.0
# 8        0.429        0.857         0.258      27.0  ...     -105.0
# 9        0.534        0.655         0.500      35.0  ...     -105.0
#
#    PTS_comb_actual  book_name_under  book_id_under  total1_under  under_odds  \
# 0            210.0  Pinnacle Sports            238         222.5       108.0
# 1            207.0        Bookmaker             93         216.0      -102.0
# 2            216.0  Pinnacle Sports            238         215.5      -102.0
# 3            228.0           5Dimes             19         209.0      -105.0
# 4            238.0         Heritage            169         228.0      -105.0
# 5            188.0  Pinnacle Sports            238         196.5      -105.0
# 6            215.0           5Dimes             19         192.0      -105.0
# 7            199.0           Bovada         999996         196.0      -110.0
# 8            202.0  Pinnacle Sports            238         225.0      -105.0
# 9            240.0  Pinnacle Sports            238         217.5      -105.0
#
#    point_average_last10  point_againts_average_last10  \
# 0            116.226415                    104.320755
# 1            104.435540                    111.298407
# 2             99.916667                    107.183333
# 3            105.028571                    107.771429
# 4            109.972222                    104.277778
# 5            102.906250                    104.125000
# 6            100.800000                     95.400000
# 7            103.416667                     94.816667
# 8            105.172619                    108.437500
# 9            110.292271                    108.974638
#
#   away_point_average_last10  away_point_againts_average_last10
# 0                111.176893                         110.534142
# 1                105.205303                         105.693687
# 2                110.787037                         104.050926
# 3                101.091912                         104.283088
# 4                105.366667                         115.866667
# 5                 96.233333                         106.366667
# 6                109.583333                          99.666667
# 7                 93.112500                         102.887500
# 8                108.260417                         106.833333
# 9                106.501374                         101.627747
#
# [10 rows x 31 columns]

# %%
# Rename columns 
nba_df.rename(columns = {'point_againts_average_last10':'point_against_average_last10', 'away_point_againts_average_last10':'away_point_against_average_last10'}, inplace = True)

# %%
# Drop non-beneficial columns if applicable 
# nba_df.drop(columns=[''], inplace=True)

# %%
# Determine the number of unique values in each column.
nba_df.nunique()
# Out:
# GAME_DATE_EST                         198
# game_id                              1210
# home_team                              30
# away_team                              30
# SEASON                                  1
# PTS_home                               68
# FG_PCT_home                           223
# FT_PCT_home                           174
# FG3_PCT_home                          219
# AST_home                               29
# REB_home                               37
# PTS_away                               68
# FG_PCT_away                           225
# FT_PCT_away                           181
# FG3_PCT_away                          207
# AST_away                               33
# REB_away                               42
# HOME_TEAM_WINS                          2
# book_name_over                          9
# book_id_over                            9
# total1_over                            92
# over_odds                              21
# PTS_comb_actual                       106
# book_name_under                         8
# book_id_under                           8
# total1_under                           89
# under_odds                             22
# point_average_last10                  491
# point_against_average_last10          481
# away_point_average_last10             495
# away_point_against_average_last10     484
# dtype: int64

# %%
# Look at actual game points value counts for binning
nba_df['PTS_comb_actual'].value_counts()
# Out:
# 215.0    34
# 207.0    33
# 205.0    27
# 213.0    27
# 211.0    27
#          ..
# 255.0     1
# 250.0     1
# 158.0     1
# 171.0     1
# 166.0     1
# Name: PTS_comb_actual, Length: 106, dtype: int64

# %%
# Choose a cutoff value and create a list of actual game points to be replaced
# use the variable name `pts_types_to_replace`
pts_types = pd.DataFrame(nba_df['PTS_comb_actual'].value_counts()).reset_index()

pts_types_to_replace = []

for index, row in pts_types.iterrows():
    if row['PTS_comb_actual'] < 10:
        pts_types_to_replace.append(row['index'])
pts_types_to_replace 


# Replace in dataframe
for pts_types in pts_types_to_replace:
    nba_df['PTS_comb_actual'] = nba_df['PTS_comb_actual'].replace(pts_types,"Other")

# Check to make sure binning was successful
nba_df['PTS_comb_actual'].value_counts()
# Out:
# Other    189
# 215.0     34
# 207.0     33
# 213.0     27
# 206.0     27
# 205.0     27
# 211.0     27
# 217.0     26
# 192.0     25
# 208.0     25
# 209.0     25
# 223.0     25
# 204.0     24
# 202.0     24
# 218.0     24
# 221.0     24
# 224.0     23
# 201.0     23
# 226.0     23
# 227.0     22
# 225.0     21
# 193.0     21
# 210.0     21
# 233.0     20
# 187.0     20
# 220.0     19
# 212.0     19
# 203.0     19
# 200.0     19
# 214.0     18
# 195.0     17
# 197.0     17
# 231.0     17
# 191.0     16
# 190.0     16
# 196.0     16
# 232.0     15
# 219.0     15
# 234.0     15
# 198.0     14
# 189.0     14
# 228.0     14
# 216.0     14
# 237.0     14
# 241.0     13
# 194.0     13
# 240.0     13
# 229.0     13
# 199.0     13
# 188.0     13
# 230.0     11
# 236.0     11
# 235.0     11
# 242.0     11
# Name: PTS_comb_actual, dtype: int64

# %%
# Look at point-average-last10 value counts for binning
# Try other columns
pa_counts = nba_df['point_average_last10'].value_counts()
pa_counts
# Out:
# 107.050000    10
# 101.050000     9
# 102.150000     9
# 105.650000     9
# 102.250000     9
#               ..
# 108.225000     1
# 93.337500      1
# 98.750000      1
# 102.011111     1
# 101.300000     1
# Name: point_average_last10, Length: 491, dtype: int64

# %%
# Choose a cutoff value and create a list of YYYY to be replaced
# use the variable name `yyyy_to_replace`
pa_types = pd.DataFrame(nba_df['point_average_last10'].value_counts()).reset_index()

pa_to_replace = []

for index, row in pa_types.iterrows():
    if row['point_average_last10'] < 5:
        pa_to_replace.append(row['index'])
pa_to_replace 

# Replace in dataframe
for pa_types in pa_to_replace:
    nba_df['point_average_last10'] = nba_df['point_average_last10'].replace(pa_types,"Other")
    
# Check to make sure binning was successful
nba_df['point_average_last10'].value_counts()
# Out:
# Other    1210
# Name: point_average_last10, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
nba_df = pd.get_dummies(nba_df)

# %%
# Split our preprocessed data into our features and target arrays
y = nba_df['HOME_TEAM_WINS']
X = nba_df.drop(columns=['HOME_TEAM_WINS'])

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
from tensorflow import keras
from tensorflow.keras import layers
num_input_features = len(X_train_scaled[0])

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(layers.Dense(units = 100, activation = 'relu', input_dim = num_input_features))

# Second hidden layer
nn.add(layers.Dense(units = 50, activation = 'elu'))

# Output layer
nn.add(layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 100)               29600
#
#  dense_16 (Dense)            (None, 50)                5050
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 34701 (135.55 KB)
# Trainable params: 34701 (135.55 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss ='binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Train the model
fit_modelnn = nn.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 1s 2ms/step - loss: 0.6867 - accuracy: 0.5998
# Epoch 2/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.3936 - accuracy: 0.8534
# Epoch 3/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.2440 - accuracy: 0.9250
# Epoch 4/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.1440 - accuracy: 0.9713
# Epoch 5/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9879
# Epoch 6/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0492 - accuracy: 0.9978
# Epoch 7/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9967
# Epoch 8/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0205 - accuracy: 1.0000
# Epoch 9/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 10/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 11/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 12/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 13/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 14/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 15/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 16/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 17/100
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 18/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 19/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 20/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 21/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 22/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 23/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 24/100
# 29/29 [==============================] - 0s 3ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 25/100
# 29/29 [==============================] - 0s 3ms/step - loss: 9.4472e-04 - accuracy: 1.0000
# Epoch 26/100
# 29/29 [==============================] - 0s 2ms/step - loss: 8.6073e-04 - accuracy: 1.0000
# Epoch 27/100
# 29/29 [==============================] - 0s 2ms/step - loss: 7.8638e-04 - accuracy: 1.0000
# Epoch 28/100
# 29/29 [==============================] - 0s 3ms/step - loss: 7.2474e-04 - accuracy: 1.0000
# Epoch 29/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.7125e-04 - accuracy: 1.0000
# Epoch 30/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.2109e-04 - accuracy: 1.0000
# Epoch 31/100
# 29/29 [==============================] - 0s 3ms/step - loss: 5.7635e-04 - accuracy: 1.0000
# Epoch 32/100
# 29/29 [==============================] - 0s 3ms/step - loss: 5.3660e-04 - accuracy: 1.0000
# Epoch 33/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.9877e-04 - accuracy: 1.0000
# Epoch 34/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.6719e-04 - accuracy: 1.0000
# Epoch 35/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.3839e-04 - accuracy: 1.0000
# Epoch 36/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.1107e-04 - accuracy: 1.0000
# Epoch 37/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.8406e-04 - accuracy: 1.0000
# Epoch 38/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.6221e-04 - accuracy: 1.0000
# Epoch 39/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.4422e-04 - accuracy: 1.0000
# Epoch 40/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.2222e-04 - accuracy: 1.0000
# Epoch 41/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.0413e-04 - accuracy: 1.0000
# Epoch 42/100
# 29/29 [==============================] - 0s 3ms/step - loss: 2.8801e-04 - accuracy: 1.0000
# Epoch 43/100
# 29/29 [==============================] - 0s 3ms/step - loss: 2.7289e-04 - accuracy: 1.0000
# Epoch 44/100
# 29/29 [==============================] - 0s 3ms/step - loss: 2.5947e-04 - accuracy: 1.0000
# Epoch 45/100
# 29/29 [==============================] - 0s 3ms/step - loss: 2.4688e-04 - accuracy: 1.0000
# Epoch 46/100
# 29/29 [==============================] - 0s 4ms/step - loss: 2.3408e-04 - accuracy: 1.0000
# Epoch 47/100
# 29/29 [==============================] - 0s 4ms/step - loss: 2.2267e-04 - accuracy: 1.0000
# Epoch 48/100
# 29/29 [==============================] - 0s 3ms/step - loss: 2.1245e-04 - accuracy: 1.0000
# Epoch 49/100
# 29/29 [==============================] - 0s 4ms/step - loss: 2.0278e-04 - accuracy: 1.0000
# Epoch 50/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.9404e-04 - accuracy: 1.0000
# Epoch 51/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.8543e-04 - accuracy: 1.0000
# Epoch 52/100
# 29/29 [==============================] - 0s 4ms/step - loss: 1.7727e-04 - accuracy: 1.0000
# Epoch 53/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6954e-04 - accuracy: 1.0000
# Epoch 54/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.6245e-04 - accuracy: 1.0000
# Epoch 55/100
# 29/29 [==============================] - 0s 4ms/step - loss: 1.5581e-04 - accuracy: 1.0000
# Epoch 56/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4931e-04 - accuracy: 1.0000
# Epoch 57/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.4337e-04 - accuracy: 1.0000
# Epoch 58/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3762e-04 - accuracy: 1.0000
# Epoch 59/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.3212e-04 - accuracy: 1.0000
# Epoch 60/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2732e-04 - accuracy: 1.0000
# Epoch 61/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.2234e-04 - accuracy: 1.0000
# Epoch 62/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1773e-04 - accuracy: 1.0000
# Epoch 63/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.1392e-04 - accuracy: 1.0000
# Epoch 64/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0964e-04 - accuracy: 1.0000
# Epoch 65/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0563e-04 - accuracy: 1.0000
# Epoch 66/100
# 29/29 [==============================] - 0s 3ms/step - loss: 1.0183e-04 - accuracy: 1.0000
# Epoch 67/100
# 29/29 [==============================] - 0s 3ms/step - loss: 9.8366e-05 - accuracy: 1.0000
# Epoch 68/100
# 29/29 [==============================] - 0s 3ms/step - loss: 9.4881e-05 - accuracy: 1.0000
# Epoch 69/100
# 29/29 [==============================] - 0s 3ms/step - loss: 9.1733e-05 - accuracy: 1.0000
# Epoch 70/100
# 29/29 [==============================] - 0s 4ms/step - loss: 8.8567e-05 - accuracy: 1.0000
# Epoch 71/100
# 29/29 [==============================] - 0s 3ms/step - loss: 8.5492e-05 - accuracy: 1.0000
# Epoch 72/100
# 29/29 [==============================] - 0s 3ms/step - loss: 8.2849e-05 - accuracy: 1.0000
# Epoch 73/100
# 29/29 [==============================] - 0s 3ms/step - loss: 8.0178e-05 - accuracy: 1.0000
# Epoch 74/100
# 29/29 [==============================] - 0s 3ms/step - loss: 7.7531e-05 - accuracy: 1.0000
# Epoch 75/100
# 29/29 [==============================] - 0s 4ms/step - loss: 7.5098e-05 - accuracy: 1.0000
# Epoch 76/100
# 29/29 [==============================] - 0s 4ms/step - loss: 7.2766e-05 - accuracy: 1.0000
# Epoch 77/100
# 29/29 [==============================] - 0s 4ms/step - loss: 7.0376e-05 - accuracy: 1.0000
# Epoch 78/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.8183e-05 - accuracy: 1.0000
# Epoch 79/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.6106e-05 - accuracy: 1.0000
# Epoch 80/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.4050e-05 - accuracy: 1.0000
# Epoch 81/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.2264e-05 - accuracy: 1.0000
# Epoch 82/100
# 29/29 [==============================] - 0s 3ms/step - loss: 6.0312e-05 - accuracy: 1.0000
# Epoch 83/100
# 29/29 [==============================] - 0s 4ms/step - loss: 5.8601e-05 - accuracy: 1.0000
# Epoch 84/100
# 29/29 [==============================] - 0s 3ms/step - loss: 5.6853e-05 - accuracy: 1.0000
# Epoch 85/100
# 29/29 [==============================] - 0s 3ms/step - loss: 5.5142e-05 - accuracy: 1.0000
# Epoch 86/100
# 29/29 [==============================] - 0s 4ms/step - loss: 5.3460e-05 - accuracy: 1.0000
# Epoch 87/100
# 29/29 [==============================] - 0s 4ms/step - loss: 5.2061e-05 - accuracy: 1.0000
# Epoch 88/100
# 29/29 [==============================] - 0s 3ms/step - loss: 5.0471e-05 - accuracy: 1.0000
# Epoch 89/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.9026e-05 - accuracy: 1.0000
# Epoch 90/100
# 29/29 [==============================] - 0s 4ms/step - loss: 4.7605e-05 - accuracy: 1.0000
# Epoch 91/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.6330e-05 - accuracy: 1.0000
# Epoch 92/100
# 29/29 [==============================] - 0s 4ms/step - loss: 4.5064e-05 - accuracy: 1.0000
# Epoch 93/100
# 29/29 [==============================] - 0s 4ms/step - loss: 4.3859e-05 - accuracy: 1.0000
# Epoch 94/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.2691e-05 - accuracy: 1.0000
# Epoch 95/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.1444e-05 - accuracy: 1.0000
# Epoch 96/100
# 29/29 [==============================] - 0s 3ms/step - loss: 4.0377e-05 - accuracy: 1.0000
# Epoch 97/100
# 29/29 [==============================] - 0s 4ms/step - loss: 3.9310e-05 - accuracy: 1.0000
# Epoch 98/100
# 29/29 [==============================] - 0s 4ms/step - loss: 3.8158e-05 - accuracy: 1.0000
# Epoch 99/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.7151e-05 - accuracy: 1.0000
# Epoch 100/100
# 29/29 [==============================] - 0s 3ms/step - loss: 3.6198e-05 - accuracy: 1.0000

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10/10 - 0s - loss: 0.7626 - accuracy: 0.8383 - 187ms/epoch - 19ms/step
# Loss: 0.7625561356544495, Accuracy: 0.8382838368415833
