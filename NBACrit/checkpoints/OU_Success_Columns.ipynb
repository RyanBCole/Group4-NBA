# %%
import pandas as pd

# %%
best_bets = pd.read_csv(r'C:\Users\redye\Desktop\NBACrit\merged_df.csv')

# %% [markdown]
# best_bets

# %%
best_bets["over_successful"] = best_bets["PTS_comb_actual"] - best_bets["total1_over"]

# Map the values to 1 or 0 based on the conditions
best_bets["over_successful"] = best_bets["over_successful"].apply(lambda x: 1 if x >= 0 else 0)
best_bets
# Out:
#      GAME_DATE_EST   game_id   home_team   away_team  SEASON  PTS_home  \
# 0        9/30/2017  11700001  1610612744  1610612743    2017       102
# 1        9/30/2017  11700002  1610612747  1610612750    2017        99
# 2        11/1/2017  21700111  1610612752  1610612745    2017        97
# 3        11/1/2017  21700107  1610612755  1610612737    2017       119
# 4        11/1/2017  21700108  1610612764  1610612756    2017       116
# ...            ...       ...         ...         ...     ...       ...
# 1205     5/28/2018  41700317  1610612745  1610612744    2017        92
# 1206     5/31/2018  41700401  1610612744  1610612739    2017       124
# 1207      6/3/2018  41700402  1610612744  1610612739    2017       122
# 1208      6/6/2018  41700403  1610612739  1610612744    2017       102
# 1209      6/8/2018  41700404  1610612739  1610612744    2017        85
#
#       FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  PTS_comb_actual  \
# ...

# %%
best_bets["under_successful"] = best_bets["total1_under"] - best_bets["PTS_comb_actual"]

# Map the values to 1 or 0 based on the conditions
best_bets["under_successful"] = best_bets["under_successful"].apply(lambda x: 1 if x >= 0 else 0)
best_bets
# Out:
#      GAME_DATE_EST   game_id   home_team   away_team  SEASON  PTS_home  \
# 0        9/30/2017  11700001  1610612744  1610612743    2017       102
# 1        9/30/2017  11700002  1610612747  1610612750    2017        99
# 2        11/1/2017  21700111  1610612752  1610612745    2017        97
# 3        11/1/2017  21700107  1610612755  1610612737    2017       119
# 4        11/1/2017  21700108  1610612764  1610612756    2017       116
# ...            ...       ...         ...         ...     ...       ...
# 1205     5/28/2018  41700317  1610612745  1610612744    2017        92
# 1206     5/31/2018  41700401  1610612744  1610612739    2017       124
# 1207      6/3/2018  41700402  1610612744  1610612739    2017       122
# 1208      6/6/2018  41700403  1610612739  1610612744    2017       102
# 1209      6/8/2018  41700404  1610612739  1610612744    2017        85
#
#       FG_PCT_home  FT_PCT_home  FG3_PCT_home  AST_home  ...  book_name_under  \
# ...

# %%
best_bets.to_csv(r'C:\Users\redye\Desktop\NBACrit\merged_df2.csv')

# %%
best_bets['under_successful'].sum()
# Out:
# 635

# %%
best_bets['over_successful'].sum()
# Out:
# 604

# %%
new_df = best_bets[best_bets["over_successful"] == best_bets["under_successful"]].copy()

# %%
new_df
# Out:
#      GAME_DATE_EST   game_id   home_team   away_team  SEASON  PTS_home  \
# 33       11/5/2017  21700137  1610612746  1610612748    2017       101
# 152     11/22/2017  21700254  1610612739  1610612751    2017       119
# 239      12/4/2017  21700340  1610612754  1610612752    2017       115
# 254      12/6/2017  21700355  1610612753  1610612737    2017       110
# 255      12/6/2017  21700359  1610612749  1610612765    2017       104
# 288     12/11/2017  21700391  1610612741  1610612738    2017       108
# 326     12/16/2017  21700436  1610612763  1610612738    2017        93
# 419     12/29/2017  21700521  1610612764  1610612745    2017       121
# 476       1/6/2018  21700583  1610612764  1610612749    2017       103
# 481       1/6/2018  21700578  1610612746  1610612744    2017       105
# 482       1/6/2018  21700581  1610612754  1610612741    2017       125
# 614      1/26/2018  21700720  1610612740  1610612745    2017       115
# ...

# %%
columns_to_keep = ["total1_under", "under_odds", "total1_over", "over_odds"]
third_df = new_df[columns_to_keep].copy()
third_df
# Out:
#       total1_under  under_odds  total1_over  over_odds
# 33           205.0        -105        205.0       -101
# 152          228.0        -109        227.5       -105
# 239          212.0        -109        211.5       -102
# 254          216.0        -105        215.5       -105
# 255          204.0        -103        204.0       -105
# 288          193.5        -105        193.0       -105
# 326          195.0        -105        195.0       -102
# 419          225.0        -104        223.0       -115
# 476          213.5        -103        213.0       -102
# 481          226.0        -105        225.5        100
# 482          212.0        -101        211.0       -105
# 614          229.0        -115        228.0       -100
# 618          223.0        -105        223.0       -101
# 740          222.0        -105        220.5       -110
# 771          208.5        -105        208.0       -105
# 772          209.0        -105        209.0       -103
# ...
